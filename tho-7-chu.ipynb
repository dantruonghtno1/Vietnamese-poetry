# %%
import torch
from transformers import GPT2Tokenizer, GPT2LMHeadModel,AutoTokenizer,Trainer,TrainingArguments,GPT2Config
from torch.utils.data.dataloader import DataLoader, Dataset
import os
import tqdm
from random import randint
import glob

# %%
files_name =[file for file in glob.glob("../input/tho-7-chu/7 chu/*.txt")]
files_name = sorted(files_name)
files_name = files_name[:22000]

# %%
sentences = []

for file in files_name:
    with open(file, 'r') as fr:
        data = fr.read()
        sentences.append(data)
        
sentences = "\n".join(sentences)
with open('data.txt', 'w') as f:
    f.write(sentences)

# %%
tokenizer = AutoTokenizer.from_pretrained("vinai/phobert-base", use_fast=False)
tokenizer.add_tokens('\n')
# Out:
# Downloading:   0%|          | 0.00/557 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/874k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.08M [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# 1

# %%
tokenizer.convert_tokens_to_ids(tokenizer.pad_token)
# Out:
# 1

# %%
tokenizer
# Out:
# PreTrainedTokenizer(name_or_path='vinai/phobert-base', vocab_size=64000, model_max_len=256, is_fast=False, padding_side='right', special_tokens={'bos_token': '<s>', 'eos_token': '</s>', 'unk_token': '<unk>', 'sep_token': '</s>', 'pad_token': '<pad>', 'cls_token': '<s>', 'mask_token': '<mask>'})

# %%
tokenizer.convert_tokens_to_ids(tokenizer.bos_token)
# Out:
# 0

# %%
tokenizer.convert_tokens_to_ids(tokenizer.eos_token)
# Out:
# 2

# %%
class CustomerDataset(Dataset):
    def __init__(self,tokenizer,file_path,block_size: int):
        block_size = block_size - tokenizer.num_special_tokens_to_add(pair=False)
#         print(f"block_size = {block_size}")
        self.examples = []
        self.mask = []
        for file in file_path:
            with open(file, encoding="utf-8") as f:
                text = f.read()
            # text --> token-->number
            tokenized_text = tokenizer.convert_tokens_to_ids(tokenizer.tokenize(text))

            if len(tokenized_text) < block_size:
                inds = [tokenizer.convert_tokens_to_ids(tokenizer.bos_token)] + tokenized_text + [tokenizer.convert_tokens_to_ids(tokenizer.eos_token)] + \
            (block_size - len(tokenized_text)) * [tokenizer.convert_tokens_to_ids(tokenizer.pad_token)]
                mask = [x != tokenizer.convert_tokens_to_ids(tokenizer.pad_token) for x in inds]
#                 print(mask)
            else:
                inds = [tokenizer.convert_tokens_to_ids(tokenizer.bos_token)] + tokenized_text[:block_size] + [tokenizer.convert_tokens_to_ids(tokenizer.eos_token)]
                mask = [1] * len(inds)

            self.examples.append(inds) 
            self.mask.append(mask)
            
    def __len__(self):
        return len(self.examples)

    def __getitem__(self, i) -> torch.Tensor:
        return {
            "input_ids":torch.tensor(self.examples[i], dtype=torch.long), 
            "attention_mask":torch.tensor(self.mask[i], dtype = torch.long)
        }

# %%
from transformers import LineByLineTextDataset, DataCollatorForLanguageModeling, LineByLineWithSOPTextDataset

def load_dataset(train_path, tokenizer):
    train_dataset = CustomerDataset(
          tokenizer=tokenizer,
          file_path=train_path,
          block_size= 256)#256
    
    data_collator = DataCollatorForLanguageModeling(
        tokenizer=tokenizer, mlm=False,
    )
    return train_dataset,data_collator

# %%
train_path = ["../input/tho-7-chu/7 chu/100018.txt"]
train_dataset,data_collator = load_dataset(train_path,tokenizer)

# %%
files_name =[file for file in glob.glob("../input/tho-7-chu/7 chu/*.txt")]
files_name = sorted(files_name)
files_name = files_name[:22000]

# %%
train_dataset,data_collator = load_dataset(files_name,tokenizer)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
model = GPT2LMHeadModel.from_pretrained('danghuy1999/gpt2-viwiki')
rand_weight = torch.rand(model.lm_head.weight.shape)
model.lm_head.weight = torch.nn.parameter.Parameter(rand_weight)
task_gpt2 = {"text-generation": {"do_sample": True, "max_length": 256}} 
configuration = GPT2Config(vocab_size=64002, n_positions=260, n_ctx=260,
                           task_specific_params=task_gpt2,
                           eos_token_id = 2,
                           bos_token_id = 0,
                           pad_token_id = 1,
                           sep_token_id = 2,)
model = GPT2LMHeadModel(configuration)
model.resize_token_embeddings(len(tokenizer))
model = model.to(device)
# Out:
# Downloading:   0%|          | 0.00/916 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/487M [00:00<?, ?B/s]
# Some weights of the model checkpoint at danghuy1999/gpt2-viwiki were not used when initializing GPT2LMHeadModel: ['multiple_choice_head.summary.bias', 'multiple_choice_head.summary.weight']
# - This IS expected if you are initializing GPT2LMHeadModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing GPT2LMHeadModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
# model = GPT2LMHeadModel.from_pretrained('../input/7chucheckpoint/checkpoint-30000/checkpoint-30000')

# %%
from transformers.trainer_callback import TrainerCallback
from transformers import pipeline

training_args = TrainingArguments(
    output_dir="./output_dir", 
    overwrite_output_dir=True,
    num_train_epochs=40,
    per_device_train_batch_size=8,
    per_device_eval_batch_size=16, 
    save_steps=1000,
    save_total_limit = 2,
    warmup_steps=1000, 
    logging_steps=100,
    report_to="wandb"
    )

# %%
device = torch.device('cuda')
trainer = Trainer(
    model=model, 
    args=training_args,
    data_collator=data_collator,
    train_dataset=train_dataset,
)

# %%
trainer.train()
# Out:
# ***** Running training *****
#   Num examples = 22000
#   Num Epochs = 40
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 110000
# Automatic Weights & Biases logging enabled, to disable set os.environ["WANDB_DISABLED"] = "true"
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:  ········································
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
#                     Syncing run <strong><a href="https://wandb.ai/dantruonghtno1/huggingface/runs/3qsw902r" target="_blank">./output_dir</a></strong> to <a href="https://wandb.ai/dantruonghtno1/huggingface" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
#     <div>
#
#       <progress value='58072' max='110000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 58072/110000 5:43:50 < 5:07:28, 2.81 it/s, Epoch 21.12/40]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100</td>
#       <td>10.195700</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>9.179500</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>8.093400</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>7.091700</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>6.649900</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>6.484700</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>6.300700</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>6.211400</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>6.111400</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>6.010000</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>5.954900</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>5.870200</td>
#     </tr>
#     <tr>
#       <td>1300</td>
#       <td>5.772600</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>5.686800</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>5.609200</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>5.586800</td>
#     </tr>
#     <tr>
#       <td>1700</td>
#       <td>5.499000</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>5.497800</td>
#     </tr>
#     <tr>
#       <td>1900</td>
#       <td>5.451300</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>5.373000</td>
#     </tr>
#     <tr>
#       <td>2100</td>
#       <td>5.371400</td>
#     </tr>
#     <tr>
#       <td>2200</td>
#       <td>5.307600</td>
#     </tr>
#     <tr>
#       <td>2300</td>
#       <td>5.269100</td>
#     </tr>
#     <tr>
#       <td>2400</td>
#       <td>5.245200</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>5.224800</td>
#     </tr>
#     <tr>
#       <td>2600</td>
#       <td>5.162600</td>
#     </tr>
#     <tr>
#       <td>2700</td>
#       <td>5.134900</td>
#     </tr>
#     <tr>
#       <td>2800</td>
#       <td>5.078500</td>
#     </tr>
#     <tr>
#       <td>2900</td>
#       <td>5.037900</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>5.008300</td>
#     </tr>
#     <tr>
#       <td>3100</td>
#       <td>4.978000</td>
#     </tr>
#     <tr>
#       <td>3200</td>
#       <td>4.937500</td>
#     </tr>
#     <tr>
#       <td>3300</td>
#       <td>4.955100</td>
#     </tr>
#     <tr>
#       <td>3400</td>
#       <td>4.885900</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>4.852400</td>
#     </tr>
#     <tr>
#       <td>3600</td>
#       <td>4.830200</td>
#     </tr>
#     <tr>
#       <td>3700</td>
#       <td>4.792900</td>
#     </tr>
#     <tr>
#       <td>3800</td>
#       <td>4.802900</td>
#     </tr>
#     <tr>
#       <td>3900</td>
#       <td>4.824100</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>4.793800</td>
#     </tr>
#     <tr>
#       <td>4100</td>
#       <td>4.718600</td>
#     </tr>
#     <tr>
#       <td>4200</td>
#       <td>4.756600</td>
#     </tr>
#     <tr>
#       <td>4300</td>
#       <td>4.772500</td>
#     </tr>
#     <tr>
#       <td>4400</td>
#       <td>4.743600</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>4.695600</td>
#     </tr>
#     <tr>
#       <td>4600</td>
#       <td>4.677600</td>
#     </tr>
#     <tr>
#       <td>4700</td>
#       <td>4.689400</td>
#     </tr>
#     <tr>
#       <td>4800</td>
#       <td>4.621400</td>
#     </tr>
#     <tr>
#       <td>4900</td>
#       <td>4.606600</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>4.592600</td>
#     </tr>
#     <tr>
#       <td>5100</td>
#       <td>4.621600</td>
#     </tr>
#     <tr>
#       <td>5200</td>
#       <td>4.557400</td>
#     </tr>
#     <tr>
#       <td>5300</td>
#       <td>4.557700</td>
#     </tr>
#     <tr>
#       <td>5400</td>
#       <td>4.595200</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>4.564100</td>
#     </tr>
#     <tr>
#       <td>5600</td>
#       <td>4.400600</td>
#     </tr>
#     <tr>
#       <td>5700</td>
#       <td>4.394800</td>
#     </tr>
#     <tr>
#       <td>5800</td>
#       <td>4.380000</td>
#     </tr>
#     <tr>
#       <td>5900</td>
#       <td>4.421700</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>4.393400</td>
#     </tr>
#     <tr>
#       <td>6100</td>
#       <td>4.343600</td>
#     </tr>
#     <tr>
#       <td>6200</td>
#       <td>4.363200</td>
#     </tr>
#     <tr>
#       <td>6300</td>
#       <td>4.332600</td>
#     </tr>
#     <tr>
#       <td>6400</td>
#       <td>4.295100</td>
#     </tr>
#     <tr>
#       <td>6500</td>
#       <td>4.354500</td>
#     </tr>
#     <tr>
#       <td>6600</td>
#       <td>4.348100</td>
#     </tr>
#     <tr>
#       <td>6700</td>
#       <td>4.284000</td>
#     </tr>
#     <tr>
#       <td>6800</td>
#       <td>4.294600</td>
#     </tr>
#     <tr>
#       <td>6900</td>
#       <td>4.274900</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>4.290600</td>
#     </tr>
#     <tr>
#       <td>7100</td>
#       <td>4.339900</td>
#     </tr>
#     <tr>
#       <td>7200</td>
#       <td>4.288500</td>
#     </tr>
#     <tr>
#       <td>7300</td>
#       <td>4.260700</td>
#     </tr>
#     <tr>
#       <td>7400</td>
#       <td>4.248200</td>
#     </tr>
#     <tr>
#       <td>7500</td>
#       <td>4.238200</td>
#     </tr>
#     <tr>
#       <td>7600</td>
#       <td>4.235500</td>
#     </tr>
#     <tr>
#       <td>7700</td>
#       <td>4.287900</td>
#     </tr>
#     <tr>
#       <td>7800</td>
#       <td>4.221900</td>
#     </tr>
#     <tr>
#       <td>7900</td>
#       <td>4.244400</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>4.237600</td>
#     </tr>
#     <tr>
#       <td>8100</td>
#       <td>4.236900</td>
#     </tr>
#     <tr>
#       <td>8200</td>
#       <td>4.185600</td>
#     </tr>
#     <tr>
#       <td>8300</td>
#       <td>4.158900</td>
#     </tr>
#     <tr>
#       <td>8400</td>
#       <td>4.034300</td>
#     </tr>
#     <tr>
#       <td>8500</td>
#       <td>4.023500</td>
#     </tr>
#     <tr>
#       <td>8600</td>
#       <td>3.986200</td>
#     </tr>
#     <tr>
#       <td>8700</td>
#       <td>4.020800</td>
#     </tr>
#     <tr>
#       <td>8800</td>
#       <td>4.045600</td>
#     </tr>
#     <tr>
#       <td>8900</td>
#       <td>3.983700</td>
#     </tr>
#     <tr>
#       <td>9000</td>
#       <td>3.997700</td>
#     </tr>
#     <tr>
#       <td>9100</td>
#       <td>4.001500</td>
#     </tr>
#     <tr>
#       <td>9200</td>
#       <td>3.966200</td>
#     </tr>
#     <tr>
#       <td>9300</td>
#       <td>4.004600</td>
#     </tr>
#     <tr>
#       <td>9400</td>
#       <td>3.997300</td>
#     </tr>
#     <tr>
#       <td>9500</td>
#       <td>3.954600</td>
#     </tr>
#     <tr>
#       <td>9600</td>
#       <td>3.989800</td>
#     </tr>
#     <tr>
#       <td>9700</td>
#       <td>3.952800</td>
#     </tr>
#     <tr>
#       <td>9800</td>
#       <td>3.976400</td>
#     </tr>
#     <tr>
#       <td>9900</td>
#       <td>3.955300</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>3.967000</td>
#     </tr>
#     <tr>
#       <td>10100</td>
#       <td>3.916600</td>
#     </tr>
#     <tr>
#       <td>10200</td>
#       <td>3.962200</td>
#     </tr>
#     <tr>
#       <td>10300</td>
#       <td>3.978900</td>
#     </tr>
#     <tr>
#       <td>10400</td>
#       <td>3.970800</td>
#     </tr>
#     <tr>
#       <td>10500</td>
#       <td>3.992000</td>
#     </tr>
#     <tr>
#       <td>10600</td>
#       <td>3.944800</td>
#     </tr>
#     <tr>
#       <td>10700</td>
#       <td>3.914600</td>
#     </tr>
#     <tr>
#       <td>10800</td>
#       <td>3.928600</td>
#     </tr>
#     <tr>
#       <td>10900</td>
#       <td>3.906400</td>
#     </tr>
#     <tr>
#       <td>11000</td>
#       <td>3.912000</td>
#     </tr>
#     <tr>
#       <td>11100</td>
#       <td>3.729300</td>
#     </tr>
#     <tr>
#       <td>11200</td>
#       <td>3.694500</td>
#     </tr>
#     <tr>
#       <td>11300</td>
#       <td>3.715400</td>
#     </tr>
#     <tr>
#       <td>11400</td>
#       <td>3.696200</td>
#     </tr>
#     <tr>
#       <td>11500</td>
#       <td>3.748000</td>
#     </tr>
#     <tr>
#       <td>11600</td>
#       <td>3.747600</td>
#     </tr>
#     <tr>
#       <td>11700</td>
#       <td>3.745300</td>
#     </tr>
#     <tr>
#       <td>11800</td>
#       <td>3.722000</td>
#     </tr>
#     <tr>
#       <td>11900</td>
#       <td>3.742000</td>
#     </tr>
#     <tr>
#       <td>12000</td>
#       <td>3.699000</td>
#     </tr>
#     <tr>
#       <td>12100</td>
#       <td>3.716200</td
# Saving model checkpoint to ./output_dir/checkpoint-1000
# Configuration saved in ./output_dir/checkpoint-1000/config.json
# Model weights saved in ./output_dir/checkpoint-1000/pytorch_model.bin
# Saving model checkpoint to ./output_dir/checkpoint-2000
# Configuration saved in ./output_dir/checkpoint-2000/config.json
# Model weights saved in ./output_dir/checkpoint-2000/pytorch_model.bin
# Saving model checkpoint to ./output_dir/checkpoint-3000
# Configuration saved in ./output_dir/checkpoint-3000/config.json
# Model weights saved in ./output_dir/checkpoint-3000/pytorch_model.bin
# Deleting older checkpoint [output_dir/checkpoint-1000] due to args.save_total_limit
# Saving model checkpoint to ./output_dir/checkpoint-4000
# Configuration saved in ./output_dir/checkpoint-4000/config.json
# Model weights saved in ./output_dir/checkpoint-4000/pytorch_model.bin
# Deleting older checkpoint [output_dir/checkpoint-2000] due to args.save_total_limit
# Saving model checkpoint to ./output_dir/checkpoint-5000
# Configuration saved in ./output_dir/checkpoint-5000/config.json
# Model weights saved in ./output_dir/checkpoint-5000/pytorch_model.bin
# Deleting older checkpoint [output_dir/checkpoint-3000] due to args.save_total_limit
# Saving model checkpoint to ./output_dir/checkpoint-6000
# Configuration saved in ./output_dir/checkpoint-6000/config.json
# Model weights saved in ./output_dir/checkpoint-6000/pytorch_model.bin
# Deleting older checkpoint [output_dir/checkpoint-4000] due to args.save_total_limit
# Saving model checkpoint to ./output_dir/checkpoint-7000
# Configuration saved in ./output_dir/checkpoint-7000/config.json
# Model weights saved in ./output_dir/checkpoint-7000/pytorch_model.bin
# Deleting older checkpoint [output_dir/checkpoint-5000] due to args.save_total_limit
# Saving model checkpoint to ./output_dir/checkpoint-8000
# Configuration saved in ./output_dir/checkpoint-8000/config.json
# Model weights saved in ./output_dir/checkpoint-8000/pytorch_model.bin
# Deleting older checkpoint [output_dir/checkpoint-6000] due to args.save_total_limit
# Saving model checkpoint to ./output_dir/checkpoint-9000
# Configuration saved in ./output_dir/checkpoint-9000/config.json
# Model weights saved in ./output_dir/checkpoint-9000/pytorch_model.bin
# Deleting older checkpoint [output_dir/checkpoint-7000] due to args.save_total_limit
# Saving model checkpoint to ./output_dir/checkpoint-10000
# Configuration saved in ./output_dir/checkpoint-10000/config.json
# Model weights saved in ./output_dir/checkpoint-10000/pytorch_model.bin
# Deleting older checkpoint [output_dir/checkpoint-8000] due to args.save_total_limit
# Saving model checkpoint to ./output_dir/checkpoint-11000
# Configuration saved in ./output_dir/checkpoint-11000/config.json
# Model weights saved in ./output_dir/checkpoint-11000/pytorch_model.bin
# Deleting older checkpoint [output_dir/checkpoint-9000] due to args.save_total_limit
# Saving model checkpoint to ./output_dir/checkpoint-12000
# Configuration saved in ./output_dir/checkpoint-12000/config.json
# Model weights saved in ./output_dir/checkpoint-12000/pytorch_model.bin
# Deleting older checkpoint [output_dir/checkpoint-10000] due to args.save_total_limit
# Saving model checkpoint to ./output_dir/checkpoint-13000
# Configuration saved in ./output_dir/checkpoint-13000/config.json
# Model weights saved in ./output_dir/checkpoint-13000/pytorch_model.bin
# Deleting older checkpoint [output_dir/checkpoint-11000] due to args.save_total_limit
# Saving model checkpoint to ./output_dir/checkpoint-14000
# Configuration saved in ./output_dir/checkpoint-14000/config.json
# Model weights saved in ./output_dir/checkpoint-14000/pytorch_model.bin
# Deleting older checkpoint [output_dir/checkpoint-12000] due to args.save_total_limit
# Saving model checkpoint to ./output_dir/checkpoint-15000
# Configuration saved in ./output_dir/checkpoint-15000/config.json
# Model weights saved in ./output_dir/checkpoint-15000/pytorch_model.bin
# Deleting older checkpoint [output_dir/checkpoint-13000] due to args.save_total_limit
# Saving model checkpoint to ./output_dir/checkpoint-16000
# Configuration saved in ./output_dir/checkpoint-16000/config.json
# Model weights saved in ./output_dir/checkpoint-16000/pytorch_model.bin
# Deleting older checkpoint [output_dir/checkpoint-14000] due to args.save_total_limit
# Saving model checkpoint to ./output_dir/checkpoint-17000
# Configuration saved in ./output_dir/checkpoint-17000/config.json
# Model weights saved in ./output_dir/checkpoint-17000/pytorch_model.bin
# Deleting older checkpoint [output_dir/checkpoint-15000] due to args.save_total_limit
# Saving model checkpoint to ./output_dir/checkpoint-18000
# Configuration saved in ./output_dir/checkpoint-18000/config.json
# Model weights saved in ./output_dir/checkpoint-18000/pytorch_model.bin
# Deleting older checkpoint [output_dir/checkpoint-16000] due to args.save_total_limit
# Saving model checkpoint to ./output_dir/checkpoint-19000
# Configuration saved in ./output_dir/checkpoint-19000/config.json
# Model weights saved in ./output_dir/checkpoint-19000/pytorch_model.bin
# Deleting older checkpoint [output_dir/checkpoint-17000] due to args.save_total_limit
# Saving model checkpoint to ./output_dir/checkpoint-20000
# Configuration saved in ./output_dir/checkpoint-20000/config.json
# Model weights saved in ./output_dir/checkpoint-20000/pytorch_model.bin
# Deleting older checkpoint [output_dir/checkpoint-18000] due to args.save_total_limit
# Saving model checkpoint to ./output_dir/checkpoint-21000
# Configuration saved in ./output_dir/checkpoint-21000/config.json
# Model weights saved in ./output_dir/checkpoint-21000/pytorch_model.bin
# Deleting older checkpoint [output_dir/checkpoint-19000] due to args.save_total_limit
# Saving model checkpoint to ./output_dir/checkpoint-22000
# Configuration saved in ./output_dir/checkpoint-22000/config.json
# Model weights saved in ./output_dir/checkpoint-22000/pytorch_model.bin
# Deleting older checkpoint [output_dir/checkpoint-20000] due to args.save_total_limit
# Saving model checkpoint to ./output_dir/checkpoint-23000
# Configuration saved in ./output_dir/checkpoint-23000/config.json
# Model weights saved in ./output_dir/checkpoint-23000/pytorch_model.bin
# Deleting older checkpoint [output_dir/checkpoint-21000] due to args.save_total_limit
# Saving model checkpoint to ./output_dir/checkpoint-24000
# Configuration saved in ./output_dir/checkpoint-24000/config.json
# Model weights saved in ./output_dir/checkpoint-24000/pytorch_model.bin
# Deleting older checkpoint [output_dir/checkpoint-22000] due to args.save_total_limit
# Saving model checkpoint to ./output_dir/checkpoint-25000
# Configuration saved in ./output_dir/checkpoint-25000/config.json
# Model weights saved in ./output_dir/checkpoint-25000/pytorch_model.bin
# Deleting older checkpoint [output_dir/checkpoint-23000] due to args.save_total_limit
# Saving model checkpoint to ./output_dir/checkpoint-26000
# Configuration saved in ./output_dir/checkpoint-26000/config.json
# Model weights saved in ./output_dir/checkpoint-26000/pytorch_model.bin
# Deleting older checkpoint [output_dir/checkpoint-24000] due to args.save_total_limit
# Saving model checkpoint to ./output_dir/checkpoint-27000
# Configuration saved in ./output_dir/checkpoint-27000/config.json
# Model weights saved in ./output_dir/checkpoint-27000/pytorch_model.bin
# Deleting older checkpoint [output_dir/checkpoint-25000] due to args.save_total_limit
# Saving model checkpoint to ./output_dir/checkpoint-28000
# Configuration saved in ./output_dir/checkpoint-28000/config.json
# Model weights saved in ./output_dir/checkpoint-28000/pytorch_model.bin
# Deleting older checkpoint [output_dir/checkpoint-26000] due to args.save_total_limit
# Saving model checkpoint to ./output_dir/checkpoint-29000
# Configuration saved in ./output_dir/checkpoint-29000/config.json
# Model weights saved in ./output_dir/checkpoint-29000/pytorch_model.bin
# Deleting older checkpoint [output_dir/checkpoint-27000] due to args.save_total_limit
# Saving model checkpoint to ./output_dir/checkpoint-30000
# Configuration saved in ./output_dir/checkpoint-30000/config.json
# Model weights saved in ./output_dir/checkpoint-30000/pytorch_model.bin
# Deleting older checkpoint [output_dir/checkpoint-28000] due to args.save_total_limit
# Saving model checkpoint to ./output_dir/checkpoint-31000
# Configuration saved in ./output_dir/checkpoint-31000/config.json
# Model weights saved in ./output_dir/checkpoint-31000/pytorch_model.bin
# Deleting older checkpoint [output_dir/checkpoint-29000] due to args.save_total_limit
# Saving model checkpoint to ./output_dir/checkpoint-32000
# Configuration saved in ./output_dir/checkpoint-32000/config.json
# Model weights saved in ./output_dir/checkpoint-32000/pytorch_model.bin
# Deleting older checkpoint [output_dir/checkpoint-30000] due to args.save_total_limit
# Saving model checkpoint to ./output_dir/checkpoint-33000
# Configuration saved in ./output_dir/checkpoint-33000/config.json
# Model weights saved in ./output_dir/checkpoint-33000/pytorch_model.bin
# Deleting older checkpoint [output_dir/checkpoint-31000] due to args.save_total_limit
# Saving model checkpoint to ./output_dir/checkpoint-34000
# Configuration saved in ./output_dir/checkpoint-34000/config.json
# Model weights saved in ./output_dir/checkpoint-34000/pytorch_model.bin
# Deleting older checkpoint [output_dir/checkpoint-32000] due to args.save_total_limit
# Saving model checkpoint to ./output_dir/checkpoint-35000
# Configuration saved in ./output_dir/checkpoint-35000/config.json
# Model weights saved in ./output_dir/checkpoint-35000/pytorch_model.bin
# Deleting older checkpoint [output_dir/checkpoint-33000] due to args.save_total_limit
# Saving model checkpoint to ./output_dir/checkpoint-36000
# Configuration saved in ./output_dir/checkpoint-36000/config.json
# Model weights saved in ./output_dir/checkpoint-36000/pytorch_model.bin
# Deleting older checkpoint [output_dir/checkpoint-34000] due to args.save_total_limit
# Saving model checkpoint to ./output_dir/checkpoint-37000
# Configuration saved in ./output_dir/checkpoint-37000/config.json
# Model weights saved in ./output_dir/checkpoint-37000/pytorch_model.bin
# Deleting older checkpoint [output_dir/checkpoint-35000] due to args.save_total_limit
# Saving model checkpoint to ./output_dir/checkpoint-38000
# Configuration saved in ./output_dir/checkpoint-38000/config.json
# Model weights saved in ./output_dir/checkpoint-38000/pytorch_model.bin
# Deleting older checkpoint [output_dir/checkpoint-36000] due to args.save_total_limit
# Saving model checkpoint to ./output_dir/checkpoint-39000
# Configuration saved in ./output_dir/checkpoint-39000/config.json
# Model weights saved in ./output_dir/checkpoint-39000/pytorch_model.bin
# Deleting older checkpoint [output_dir/checkpoint-37000] due to args.save_total_limit
# Saving model checkpoint to ./output_dir/checkpoint-40000
# Configuration saved in ./output_dir/checkpoint-40000/config.json
# Model weights saved in ./output_dir/checkpoint-40000/pytorch_model.bin
# Deleting older checkpoint [output_dir/checkpoint-38000] due to args.save_total_limit
# Saving model checkpoint to ./output_dir/checkpoint-41000
# Configuration saved in ./output_dir/checkpoint-41000/config.json
# Model weights saved in ./output_dir/checkpoint-41000/pytorch_model.bin
# Deleting older checkpoint [output_dir/checkpoint-39000] due to args.save_total_limit
# Saving model checkpoint to ./output_dir/checkpoint-42000
# Configuration saved in ./output_dir/checkpoint-42000/config.json
# Model weights saved in ./output_dir/checkpoint-42000/pytorch_model.bin
# Deleting older checkpoint [output_dir/checkpoint-40000] due to args.save_total_limit
# Saving model checkpoint to ./output_dir/checkpoint-43000
# Configuration saved in ./output_dir/checkpoint-43000/config.json
# Model weights saved in ./output_dir/checkpoint-43000/pytorch_model.bin
# Deleting older checkpoint [output_dir/checkpoint-41000] due to args.save_total_limit
# Saving model checkpoint to ./output_dir/checkpoint-44000
# Configuration saved in ./output_dir/checkpoint-44000/config.json
# Model weights saved in ./output_dir/checkpoint-44000/pytorch_model.bin
# Deleting older checkpoint [output_dir/checkpoint-42000] due to args.save_total_limit
# Saving model checkpoint to ./output_dir/checkpoint-45000
# Configuration saved in ./output_dir/checkpoint-45000/config.json
# Model weights saved in ./output_dir/checkpoint-45000/pytorch_model.bin
# Deleting older checkpoint [output_dir/checkpoint-43000] due to args.save_total_limit
# Saving model checkpoint to ./output_dir/checkpoint-46000
# Configuration saved in ./output_dir/checkpoint-46000/config.json
# Model weights saved in ./output_dir/checkpoint-46000/pytorch_model.bin
# Deleting older checkpoint [output_dir/checkpoint-44000] due to args.save_total_limit
# Saving model checkpoint to ./output_dir/checkpoint-47000
# Configuration saved in ./output_dir/checkpoint-47000/config.json
# Model weights saved in ./output_dir/checkpoint-47000/pytorch_model.bin
# Deleting older checkpoint [output_dir/checkpoint-45000] due to args.save_total_limit
# Saving model checkpoint to ./output_dir/checkpoint-48000
# Configuration saved in ./output_dir/checkpoint-48000/config.json
# Model weights saved in ./output_dir/checkpoint-48000/pytorch_model.bin
# Deleting older checkpoint [output_dir/checkpoint-46000] due to args.save_total_limit
# Saving model checkpoint to ./output_dir/checkpoint-49000
# Configuration saved in ./output_dir/checkpoint-49000/config.json
# Model weights saved in ./output_dir/checkpoint-49000/pytorch_model.bin
# Deleting older checkpoint [output_dir/checkpoint-47000] due to args.save_total_limit
# Saving model checkpoint to ./output_dir/checkpoint-50000
# Configuration saved in ./output_dir/checkpoint-50000/config.json
# Model weights saved in ./output_dir/checkpoint-50000/pytorch_model.bin
# Deleting older checkpoint [output_dir/checkpoint-48000] due to args.save_total_limit
# Saving model checkpoint to ./output_dir/checkpoint-51000
# Configuration saved in ./output_dir/checkpoint-51000/config.json
# Model weights saved in ./output_dir/checkpoint-51000/pytorch_model.bin
# Deleting older checkpoint [output_dir/checkpoint-49000] due to args.save_total_limit
# Saving model checkpoint to ./output_dir/checkpoint-52000
# Configuration saved in ./output_dir/checkpoint-52000/config.json
# Model weights saved in ./output_dir/checkpoint-52000/pytorch_model.bin
# Deleting older checkpoint [output_dir/checkpoint-50000] due to args.save_total_limit
# Saving model checkpoint to ./output_dir/checkpoint-53000
# Configuration saved in ./output_dir/checkpoint-53000/config.json
# Model weights saved in ./output_dir/checkpoint-53000/pytorch_model.bin
# Deleting older checkpoint [output_dir/checkpoint-51000] due to args.save_total_limit
# Saving model checkpoint to ./output_dir/checkpoint-54000
# Configuration saved in ./output_dir/checkpoint-54000/config.json
# Model weights saved in ./output_dir/checkpoint-54000/pytorch_model.bin
# Deleting older checkpoint [output_dir/checkpoint-52000] due to args.save_total_limit
# Saving model checkpoint to ./output_dir/checkpoint-55000
# Configuration saved in ./output_dir/checkpoint-55000/config.json
# Model weights saved in ./output_dir/checkpoint-55000/pytorch_model.bin
# Deleting older checkpoint [output_dir/checkpoint-53000] due to args.save_total_limit
# Saving model checkpoint to ./output_dir/checkpoint-56000
# Configuration saved in ./output_dir/checkpoint-56000/config.json
# Model weights saved in ./output_dir/checkpoint-56000/pytorch_model.bin
# Deleting older checkpoint [output_dir/checkpoint-54000] due to args.save_total_limit
# Saving model checkpoint to ./output_dir/checkpoint-57000
# Configuration saved in ./output_dir/checkpoint-57000/config.json
# Model weights saved in ./output_dir/checkpoint-57000/pytorch_model.bin
# Deleting older checkpoint [output_dir/checkpoint-55000] due to args.save_total_limit
# Saving model checkpoint to ./output_dir/checkpoint-58000
# Configuration saved in ./output_dir/checkpoint-58000/config.json
# Model weights saved in ./output_dir/checkpoint-58000/pytorch_model.bin
# Deleting older checkpoint [output_dir/checkpoint-56000] due to args.save_total_limit
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_34/49973641.py in <module>
# ----> 1 trainer.train()
#
# /opt/conda/lib/python3.7/site-packages/transformers/trainer.py in train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    1319                     args.logging_nan_inf_filter
#    1320                     and not is_torch_tpu_available()
# -> 1321                     and (torch.isnan(tr_loss_step) or torch.isinf(tr_loss_step))
#    1322                 ):
#    1323                     # if loss is nan or inf simply add the average of previous logged losses
#
# KeyboardInterrupt:

# %%
trainer.save_model()
# Out:
# Saving model checkpoint to ./output_dir
# Configuration saved in ./output_dir/config.json
# Model weights saved in ./output_dir/pytorch_model.bin

# %%
from transformers import pipeline
poem = pipeline('text-generation', model="./output_dir", tokenizer=tokenizer, max_length = 50)
#Test
# Out:
# loading configuration file ./output_dir/config.json
# Model config GPT2Config {
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 0,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 2,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 260,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_inner": null,
#   "n_layer": 12,
#   "n_positions": 260,
#   "pad_token_id": 1,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "sep_token_id": 2,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 256
#     }
#   },
#   "torch_dtype": "float32",
#   "transformers_version": "4.12.5",
#   "use_cache": true,
#   "vocab_size": 64002
# }
#
# loading configuration file ./output_dir/config.json
# Model config GPT2Config {
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 0,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 2,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 260,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_inner": null,
#   "n_layer": 12,
#   "n_positions": 260,
#   "pad_token_id": 1,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "sep_token_id": 2,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 256
#     }
#   },
#   "torch_dtype": "float32",
#   "transformers_version": "4.12.5",
#   "use_cache": true,
#   "vocab_size": 64002
# }
#
# loading weights file ./output_dir/pytorch_model.bin
# All model checkpoint weights were used when initializing GPT2LMHeadModel.
#
# All the weights of GPT2LMHeadModel were initialized from the model checkpoint at ./output_dir.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use GPT2LMHeadModel for predictions without further training.

# %%
a = poem('<s>yêu')
print(a[0]['generated_text'])
# Out:
# <s>yêu nhau thắm thiết áng thơ xinh
#  cách trở xa xôi kết nghĩa mình
#  duyên phận ngàn năm đời luyến nhớ
#  trăng sương vạn chuỗi ánh rung rinh
#  mộng lòng say đắm hồn phu phụ
#  chăn gối yêu thương bóng bạn tình
